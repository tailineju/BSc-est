# %% [markdown]
# # Exercise 5.01
#
# Student: DC427182

# %%
# 02: importing libraries
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 03: creating an figure
plt.figure(dpi=200)

# %%
# 04: ploting data pairs (x, y)
plt.plot([1, 2, 4, 5], [1, 3, 4, 3], '-o')
plt.show()

# %%
# 05: saving the figure
plt.plot([1, 2, 4, 5], [1, 3, 4, 3], '-o')
plt.savefig('img/Exercise5.01.png', bbox_inches='tight')
