# %% [markdown]
# # Activity 6.03
#
# Student: DC427182

# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# 01: loading the dataset
mydata = pd.read_csv('C:/Users/User/Documents/GitHub/gradest-1/DATAVIS/tutorials/Tutorial05/Datasets/iq_scores.csv')

# %%
# 02: creating test groups
group_a = mydata[mydata.columns[0]].tolist()
group_b = mydata[mydata.columns[1]].tolist()
group_c = mydata[mydata.columns[2]].tolist()
group_d = mydata[mydata.columns[3]].tolist()

# %%
# 03: creating the dataframe
data = pd.DataFrame({'Groups': ['Group A'] \
                     * len(group_a) + ['Group B'] \
                     * len(group_b) + ['Group C'] \
                     * len(group_c) + ['Group D'] \
                     * len(group_d),\
                     'IQ score': group_a + group_b \
                     + group_c + group_d})

# %%
# 04: creating a violin plot
#Use the whitegrid style, set the context to talk, and remove all axes spines, except the one on the bottom
sns.set_style('whitegrid')
sns.set_context('talk')
sns.violinplot(x='Groups', y='IQ score', data=data)
sns.despine(left=True, right=True, top=True)
plt.show()
