# %% [markdown]
# # Activity 5.6
# Student: DC427182

# %%
# 01: importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 02: loading the data
dataset = pd.read_csv('C:/Users/User/Documents/GitHub/gradest-1/DATAVIS/tutorials/Tutorial05/Datasets/anage_data.csv', index_col=0)

# %%
# 03: Filter the data so that you end up with samples containing a body mass and maximum longevity as the given dataset, AnAge, which was used in the previous exercise, is not complete. 
# Select all of the samples of the Aves class with a body mass of less than 20,000. 
dataset = dataset[dataset['Class'] == 'Aves']
dataset = dataset[dataset['Body mass (g)'] < 20000]
dataset.head()
# Out:
#      HAGRID   Kingdom    Phylum Class            Order        Family  \
# 184     192  Animalia  Chordata  Aves  Accipitriformes  Accipitridae
# 189     197  Animalia  Chordata  Aves  Accipitriformes  Accipitridae
# 199     207  Animalia  Chordata  Aves  Accipitriformes  Accipitridae
# 214     222  Animalia  Chordata  Aves  Accipitriformes  Accipitridae
# 232     240  Animalia  Chordata  Aves  Accipitriformes  Accipitridae
#
#            Genus       Species                  Common name  \
# 184    Accipiter         nisus         Eurasian sparrowhawk
# 189       Aquila    chrysaetos                 Golden eagle
# 199        Buteo      lineatus          Red-shouldered hawk
# 214  Geranoaetus  melanoleucus  Black-chested buzzard-eagle
# 232       Pernis      apivorus        Western honey-buzzard
#
#      Female maturity (days)  ...  Growth rate (1/days)  \
# 184                   365.0  ...                 0.258
# 189                  1460.0  ...                 0.126
# ...

# %%
# 04: Create a Figure with a constrained layout. Create a gridspec of size 4x4. Create a scatter plot of size 3x3 and marginal histograms of size 1x3 and 3x1. Add labels and a Figure title.

fig = plt.figure(constrained_layout=True)

gs = fig.add_gridspec(4, 4)
ax = fig.add_subplot(gs[1:, :-1])
ax_hist_x = fig.add_subplot(gs[0, :-1], sharex=ax)
ax_hist_y = fig.add_subplot(gs[1:, -1], sharey=ax)

ax.scatter(dataset['Body mass (g)'], dataset['Maximum longevity (yrs)'])
ax.set_xlabel('Body mass (g)')
ax.set_ylabel('Maximum longevity (yrs)')
ax_hist_x.hist(dataset['Body mass (g)'], bins=30, orientation='vertical')
ax_hist_y.hist(dataset['Maximum longevity (yrs)'], bins=30, orientation='horizontal')
# Out:
# (array([ 5., 16., 30., 23., 16., 11.,  9., 11., 10.,  4.,  5.,  7.,  3.,
#          2.,  3.,  0.,  1.,  2.,  1.,  1.,  2.,  1.,  0.,  0.,  1.,  0.,
#          0.,  0.,  1.,  1.]),
#  array([ 4.        ,  6.16666667,  8.33333333, 10.5       , 12.66666667,
#         14.83333333, 17.        , 19.16666667, 21.33333333, 23.5       ,
#         25.66666667, 27.83333333, 30.        , 32.16666667, 34.33333333,
#         36.5       , 38.66666667, 40.83333333, 43.        , 45.16666667,
#         47.33333333, 49.5       , 51.66666667, 53.83333333, 56.        ,
#         58.16666667, 60.33333333, 62.5       , 64.66666667, 66.83333333,
#         69.        ]),
#  <BarContainer object of 30 artists>)
