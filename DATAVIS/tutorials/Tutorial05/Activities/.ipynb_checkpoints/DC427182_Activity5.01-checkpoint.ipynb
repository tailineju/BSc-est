# %% [markdown]
# # Activity 5.01
#
# Student: DC427182

# %%
# 02: importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 03: importing the datasets
names = ("GOOGL","FB","AAPL","AMZN","MSFT")
dataset = {}
for name in names:
    dataset[name] = pd.read_csv('C:/Users/User/Documents/GitHub/gradest-1/DATAVIS/tutorials/Tutorial05/Datasets/'+name+'_data.csv')

# %%
# 04: checking the structure of one of the datasets
for name in names:
    print(dataset[name].head())
# Out:
#         date      open      high       low     close   volume   Name  year
# 0 2013-02-08  390.4551  393.7283  390.1698  393.0777  6031199  GOOGL  2013
# 1 2013-02-11  389.5892  391.8915  387.2619  391.6012  4330781  GOOGL  2013
# 2 2013-02-12  391.2659  394.3440  390.0747  390.7403  3714176  GOOGL  2013
# 3 2013-02-13  390.4551  393.0677  390.3750  391.8214  2393946  GOOGL  2013
# 4 2013-02-14  390.2549  394.7644  389.2739  394.3039  3466971  GOOGL  2013
#         date   open   high    low    close    volume Name  year
# 0 2013-02-08  28.89  29.17  28.51  28.5450  37662614   FB  2013
# 1 2013-02-11  28.61  28.68  28.04  28.2600  36979533   FB  2013
# 2 2013-02-12  27.67  28.16  27.10  27.3700  93417215   FB  2013
# 3 2013-02-13  27.36  28.32  27.31  27.9075  50100805   FB  2013
# 4 2013-02-14  28.02  28.63  28.01  28.5000  35581045   FB  2013
#         date     open     high      low    close     volume  Name  year
# ...

# %%
# 05: checking the dates (to evaluate the last 5 years)
for name in names:
    dataset[name]['date'] = pd.to_datetime(dataset[name]['date'])
    dataset[name]['year'] = dataset[name]['date'].dt.year
    print(name,": Min.",dataset[name]['year'].min(),", Max.",dataset[name]['year'].max())
# Out:
# GOOGL : Min. 2013 , Max. 2018
# FB : Min. 2013 , Max. 2018
# AAPL : Min. 2013 , Max. 2018
# AMZN : Min. 2013 , Max. 2018
# MSFT : Min. 2013 , Max. 2018

# %%
# 05: creating of grid of line charts visualizations
labels={'GOOGL':'Google','FB':'Facebook','AAPL':'Apple','AMZN':'Amazon','MSFT':'Microsoft'}

plt.figure(figsize=(12,6))
for name in names:
    plt.plot(dataset[name]['date'], dataset[name]['close'], label=labels[name])
    
plt.title('Stock Prices')
plt.xlabel('Date')
plt.ylabel('Closing price')
plt.legend(loc='upper left')
plt.grid()
plt.show()
